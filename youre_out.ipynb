# %% [markdown]
# # Finding the Will Sennet - Timothee Chalamet At Bat
#
# On 10/10/21 Will Sennet (@Senn_Spud) tweeted the following
#
# > I would strike timothee chalamet out on 3 pitches. Slider outside. He feels like hes drowning. Curveball in the dirt of course he's chasing it. Ladybird sucked kill yourself. And Bang 97 inside corner. Youre out. You were was always out. Youve been out since the day you were born
#
# This code is toy project to find if that At Bat has ever occured.

# %%
import pandas as pd
import glob
import time
from pybaseball import statcast

# %% [markdown]
# ## Gather Data
#
# Start by downloading the data via pybaseball StatCast scraper.
#
# This takes quite a while so you should save the datasets. Skip this section if you have already downloaded the data

# %%
seasons = range()
#all_data = {}

for season in seasons:
    try:
        print(f"Fetching data for {season}...")
        start_date = f"{season}-01-01"
        end_date = f"{season}-12-31"

        data = statcast(start_dt=start_date, end_dt=end_date)

        # Store in dictionary
        all_data[season] = data

        # Save to CSV (optional)
        data.to_csv(f"statcast_{season}.csv", index=False)

        # Pause to be nice to the server
        time.sleep(2)
    
    except Exception as e:
        print(f"Failed to get data for {season}: {e}")

# %%
csv_files = glob.glob("statcast_*.csv")

# %%
full_df = pd.concat((pd.read_csv(f) for f in csv_files), ignore_index = True)

# %%
full_df.to_parquet("statcast_full.parquet", index=False)

# %% [markdown]
# ## Import Data

# %%
full_df = pd.read_parquet("statcast_full.parquet")

# %% [markdown]
# ## Explore Data

# %% [markdown]
# ### Get Dataset Details

# %%
list(full_df.columns)
# Out:
# ['pitch_type',
#  'game_date',
#  'release_speed',
#  'release_pos_x',
#  'release_pos_z',
#  'player_name',
#  'batter',
#  'pitcher',
#  'events',
#  'description',
#  'spin_dir',
#  'spin_rate_deprecated',
#  'break_angle_deprecated',
#  'break_length_deprecated',
#  'zone',
#  'des',
#  'game_type',
#  'stand',
#  'p_throws',
#  'home_team',
#  'away_team',
#  'type',
#  'hit_location',
#  'bb_type',
#  'balls',
#  'strikes',
#  'game_year',
#  'pfx_x',
#  'pfx_z',
#  'plate_x',
#  'plate_z',
#  'on_3b',
#  'on_2b',
#  'on_1b',
#  'outs_when_up',
#  'inning',
#  'inning_topbot',
#  'hc_x',
#  'hc_y',
#  'tfs_deprecated',
#  'tfs_zulu_deprecated',
#  'umpire',
#  'sv_id',
#  'vx0',
#  'vy0',
#  'vz0',
#  'ax',
#  'ay',
#  'az',
#  'sz_top',
#  'sz_bot',
#  'hit_distance_sc',
#  'launch_speed',
#  'launch_angle',
#  'effective_speed',
#  'release_spin_rate',
#  'release_extension',
#  'game_pk',
#  'fielder_2',
#  'fielder_3',
#  'fielder_4',
#  'fielder_5',
#  'fielder_6',
#  'fielder_7',
#  'fielder_8',
#  'fielder_9',
#  'release_pos_y',
#  'estimated_ba_using_speedangle',
#  'estimated_woba_using_speedangle',
#  'woba_value',
#  'woba_denom',
#  'babip_value',
#  'iso_value',
#  'launch_speed_angle',
#  'at_bat_number',
#  'pitch_number',
#  'pitch_name',
#  'home_score',
#  'away_score',
#  'bat_score',
#  'fld_score',
#  'post_away_score',
#  'post_home_score',
#  'post_bat_score',
#  'post_fld_score',
#  'if_fielding_alignment',
#  'of_fielding_alignment',
#  'spin_axis',
#  'delta_home_win_exp',
#  'delta_run_exp',
#  'bat_speed',
#  'swing_length',
#  'estimated_slg_using_speedangle',
#  'delta_pitcher_run_exp',
#  'hyper_speed',
#  'home_score_diff',
#  'bat_score_diff',
#  'home_win_exp',
#  'bat_win_exp',
#  'age_pit_legacy',
#  'age_bat_legacy',
#  'age_pit',
#  'age_bat',
#  'n_thruorder_pitcher',
#  'n_priorpa_thisgame_player_at_bat',
#  'pitcher_days_since_prev_game',
#  'batter_days_since_prev_game',
#  'pitcher_days_until_next_game',
#  'batter_days_until_next_game',
#  'api_break_z_with_gravity',
#  'api_break_x_arm',
#  'api_break_x_batter_in',
#  'arm_angle']

# %%
full_df.head()
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         SL  2008-10-27           85.0          -1.24           6.85
# 1         SL  2008-10-27           85.2          -1.18           6.82
# 2         SL  2008-10-27           85.4          -1.45           6.99
# 3         SL  2008-10-27           84.9          -1.36           7.03
# 4         SL  2008-10-27           82.9          -1.17           7.04
#
#    player_name  batter  pitcher     events      description  ...  \
# 0  Lidge, Brad  400134   400058  strikeout  swinging_strike  ...
# 1  Lidge, Brad  400134   400058       None  swinging_strike  ...
# 2  Lidge, Brad  400134   400058       None             foul  ...
# 3  Lidge, Brad  450314   400058  field_out    hit_into_play  ...
# 4  Lidge, Brad  450314   400058       None    called_strike  ...
#
#    n_thruorder_pitcher  n_priorpa_thisgame_player_at_bat  \
# 0                    1                                 0
# 1                    1                                 0
# 2                    1                                 0
# 3                    1                                 0
# 4                    1                                 0
#
#    pitcher_days_since_prev_game  batter_days_since_prev_game  \
# 0                           5.0                          1.0
# 1                           5.0                          1.0
# 2                           5.0                          1.0
# 3                           5.0                          1.0
# 4                           5.0                          1.0
#
#    pitcher_days_until_next_game batter_days_until_next_game  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
#
#   api_break_z_with_gravity api_break_x_arm api_break_x_batter_in arm_angle
# 0                     3.46           -0.49                  0.49       NaN
# 1                     3.19           -0.04                  0.04       NaN
# 2                     2.91            0.21                 -0.21       NaN
# 3                     2.91            0.25                 -0.25       NaN
# 4                     3.42           -0.08                  0.08       NaN
#
# [5 rows x 113 columns]

# %%
full_df.pitch_type.value_counts()
# Out:
# pitch_type
# FF    4102583
# SI    2393636
# SL    1822820
# CH    1239179
# CU     923352
# FC     737634
# KC     235380
# FS     200294
# ST     158699
# KN      37228
# IN      32098
# SV      19333
# FA       5535
# FO       4621
# PO       4278
# EP       4169
# SC       1142
# CS        709
# AB         30
# Name: count, dtype: int64

# %% [markdown]
# ## Start Filtering

# %% [markdown]
# ### Create At Bat Key

# %%
full_df['at_bat'] = full_df.groupby(['game_date', 'inning', 'batter', 'pitcher']).ngroup()
max(full_df.at_bat)
# Out:
# 3161421

# %% [markdown]
# ### Lets Generate MLB Video Searches for each of the At Bats

# %%
full_df['at_bat_url'] = (
    "https://www.mlb.com/video/?q=Date+%3D+%5B%22" + full_df['game_date'].astype('str') + 
    "%22%5D+AND+Inning+%3D+%5B" + full_df['inning'].astype('str') +
    "%5D+AND+PlayerId+%3D%3D+%5B" + full_df['pitcher'].astype('str') + "%2C" + full_df['batter'].astype('str') +
    "%5D+Order+By+Timestamp+ASC&of=1"
)

# %% [markdown]
# ### Finding a Match True Exactly to the Tweet
#
# 1. Slider Outside
# 2. Curveball, below zone, swinging strike
# 3. Fastball, 97mph, inside corner. called strike

# %%
three_pitch_strikeouts =  full_df.at_bat[(full_df.events == 'strikeout') & (full_df.pitch_number == 3)]
len(three_pitch_strikeouts)
# Out:
# 125264

# %%
first_pitch_sliders = full_df.at_bat[(full_df.pitch_number == 1) & (full_df.pitch_type == "SL") & (full_df.zone.isin([11, 12, 13, 14])) & (full_df.at_bat.isin(three_pitch_strikeouts))]
len(first_pitch_sliders)
# Out:
# 4091

# %%
second_pitch_curveball = full_df.at_bat[(full_df.pitch_number == 2) & (full_df.pitch_type == "CU") & (full_df.zone.isin([13,14])) & (full_df.description == 'swinging_strike')  & (full_df.at_bat.isin(first_pitch_sliders))]
len(second_pitch_curveball)
# Out:
# 25

# %%
third_pitch_fastball = full_df.at_bat[(full_df.pitch_number == 3) & (full_df.pitch_type == "FF") & ((full_df.release_speed >= 96) | (full_df.effective_speed >= 96)) & ((full_df.zone.isin([1, 7]) & full_df.stand == 'L') | (full_df.zone.isin([3, 9]) & full_df.stand == 'R')) &  (full_df.description == 'called_strike') & (full_df.at_bat.isin(second_pitch_curveball))]
len(third_pitch_fastball)
# Out:
# 0

# %% [markdown]
# ### Looking for Looser Matches
#
# #### Keep Pitch Sequence and Outcomes, drop locations
#
# 1. Slider
# 2. Curveball, swinging strike
# 3. Fastball, 97 mph, called strike

# %%
first_pitch_sliders = full_df.at_bat[(full_df.pitch_number == 1) & (full_df.pitch_type == "SL") & (full_df.at_bat.isin(three_pitch_strikeouts))]
len(first_pitch_sliders)
# Out:
# 17286

# %%
second_pitch_curveball = full_df.at_bat[(full_df.pitch_number == 2) & (full_df.pitch_type == "CU") & (full_df.description == 'swinging_strike')  & (full_df.at_bat.isin(first_pitch_sliders))]
len(second_pitch_curveball)
# Out:
# 222

# %%
third_pitch_fastball = full_df.at_bat[(full_df.pitch_number == 3) & (full_df.pitch_type == "FF") & ((full_df.release_speed >= 96) | (full_df.effective_speed >= 96)) & (full_df.description == 'called_strike') & (full_df.at_bat.isin(second_pitch_curveball))]
len(third_pitch_fastball)
# Out:
# 4

# %% [markdown]
# Looks like there are four matching results, lets look more closely

# %%
full_df[full_df.at_bat.isin(third_pitch_fastball)]
# Out:
#          pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 10283174         FF  2022-06-04           96.8          -2.59           5.30
# 10283175         CU  2022-06-04           77.0          -2.53           5.65
# 10283176         SL  2022-06-04           85.5          -2.66           5.54
# 11079378         FF  2023-05-24           98.0          -2.64           5.55
# 11079379         CU  2023-05-24           81.8          -2.48           5.87
# 11079380         SL  2023-05-24           87.9          -2.68           5.73
# 11768018         FF  2024-06-12           99.1          -1.25           6.13
# 11768019         CU  2024-06-12           86.7          -1.38           5.99
# 11768020         SL  2024-06-12           89.8          -1.42           6.02
# 12034632         FF  2024-04-03           97.9          -1.27           6.06
# 12034633         CU  2024-04-03           83.8          -1.55           6.15
# 12034634         SL  2024-04-03           91.5          -1.79           5.95
#
#              player_name  batter  pitcher     events      description  ...  \
# 10283174   Oviedo, Johan  621550   670912  strikeout    called_strike  ...
# 10283175   Oviedo, Johan  621550   670912       None  swinging_strike  ...
# 10283176   Oviedo, Johan  621550   670912       None    called_strike  ...
# 11079378   Oviedo, Johan  669701   670912  strikeout    called_strike  ...
# 11079379   Oviedo, Johan  669701   670912       None  swinging_strike  ...
# 11079380   Oviedo, Johan  669701   670912       None    called_strike  ...
# 11768018   Nicolas, Kyle  680977   693312  strikeout    called_strike  ...
# 11768019   Nicolas, Kyle  680977   693312       None  swinging_strike  ...
# 11768020   Nicolas, Kyle  680977   693312       None    called_strike  ...
# 12034632  Glasnow, Tyler  642731   607192  strikeout    called_strike  ...
# 12034633  Glasnow, Tyler  642731   607192       None  swinging_strike  ...
# 12034634  Glasnow, Tyler  642731   607192       None    called_strike  ...
#
#           pitcher_days_since_prev_game  batter_days_since_prev_game  \
# 10283174                           NaN                          1.0
# 10283175                           NaN                          1.0
# 10283176                           NaN                          1.0
# 11079378                           5.0                          2.0
# 11079379                           5.0                          2.0
# 11079380                           5.0                          2.0
# 11768018                           3.0                          1.0
# 11768019                           3.0                          1.0
# 11768020                           3.0                          1.0
# 12034632                           6.0                          1.0
# 12034633                           6.0                          1.0
# 12034634                           6.0                          1.0
#
#           pitcher_days_until_next_game  batter_days_until_next_game  \
# 10283174                           4.0                          0.0
# 10283175                           4.0                          0.0
# 10283176                           4.0                          0.0
# 11079378                           6.0                          2.0
# 11079379                           6.0                          2.0
# 11079380                           6.0                          2.0
# 11768018                           3.0                          1.0
# 11768019                           3.0                          1.0
# 11768020                           3.0                          1.0
# 12034632                           6.0                          2.0
# 12034633                           6.0                          2.0
# 12034634                           6.0                          2.0
#
#           api_break_z_with_gravity api_break_x_arm api_break_x_batter_in  \
# 10283174                      1.50            0.63                  0.63
# 10283175                      4.15           -0.97                 -0.97
# 10283176                      2.49           -0.12                 -0.12
# 11079378                      1.58            0.84                 -0.84
# 11079379                      3.86           -0.85                  0.85
# 11079380                      3.05           -0.54                  0.54
# 11768018                      0.89            0.82                 -0.82
# 11768019                      4.03           -0.72                  0.72
# 11768020                      2.77           -0.45                  0.45
# 12034632                      1.06            0.09                  0.09
# 12034633                      4.01           -0.22                 -0.22
# 12034634                      2.27           -0.19                 -0.19
#
#          arm_angle   at_bat                                         at_bat_url
# 10283174      26.6  2635342  https://www.mlb.com/video/?q=Date+%3D+%5B%2220...
# 10283175      33.1  2635342  https://www.mlb.com/video/?q=Date+%3D+%5B%2220...
# 10283176      27.5  2635342  https://www.mlb.com/video/?q=Date+%3D+%5B%2220...
# 11079378      29.9  2832230  https://www.mlb.com/video/?q=Date+%3D+%5B%2220...
# 11079379      35.3  2832230  https://www.mlb.com/video/?q=Date+%3D+%5B%2220...
# 11079380      31.8  2832230  https://www.mlb.com/video/?q=Date+%3D+%5B%2220...
# 11768018      42.8  3052081  https://www.mlb.com/video/?q=Date+%3D+%5B%2220...
# 11768019      44.5  3052081  https://www.mlb.com/video/?q=Date+%3D+%5B%2220...
# 11768020      41.2  3052081  https://www.mlb.com/video/?q=Date+%3D+%5B%2220...
# 12034632      62.7  2982098  https://www.mlb.com/video/?q=Date+%3D+%5B%2220...
# 12034633      60.6  2982098  https://www.mlb.com/video/?q=Date+%3D+%5B%2220...
# 12034634      59.8  2982098  https://www.mlb.com/video/?q=Date+%3D+%5B%2220...
#
# [12 rows x 115 columns]

# %%
list(full_df.at_bat_url[full_df.at_bat.isin(third_pitch_fastball)].drop_duplicates())
# Out:
# ['https://www.mlb.com/video/?q=Date+%3D+%5B%222022-06-04%22%5D+AND+Inning+%3D+%5B3%5D+AND+PlayerId+%3D%3D+%5B670912%2C621550%5D+Order+By+Timestamp+ASC&of=1',
#  'https://www.mlb.com/video/?q=Date+%3D+%5B%222023-05-24%22%5D+AND+Inning+%3D+%5B4%5D+AND+PlayerId+%3D%3D+%5B670912%2C669701%5D+Order+By+Timestamp+ASC&of=1',
#  'https://www.mlb.com/video/?q=Date+%3D+%5B%222024-06-12%22%5D+AND+Inning+%3D+%5B8%5D+AND+PlayerId+%3D%3D+%5B693312%2C680977%5D+Order+By+Timestamp+ASC&of=1',
#  'https://www.mlb.com/video/?q=Date+%3D+%5B%222024-04-03%22%5D+AND+Inning+%3D+%5B2%5D+AND+PlayerId+%3D%3D+%5B607192%2C642731%5D+Order+By+Timestamp+ASC&of=1']

# %% [markdown]
# None are perfect matches. There is still the opportunity to be the first to pitch a Timothee Chalamet Strikeout!
